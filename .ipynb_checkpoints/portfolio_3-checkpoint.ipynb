# %%
# Portfolio 3
# Heritage data

# %%
# Det valgte dataset bliver importeret, med søge query "skitser"
# Det bliver lagt ind i et dataframe
import requests
import pandas as pd
from pandas.io.json import json_normalize

smk_search_url = 'https://api.smk.dk/api/v1/art/search/?keys=skitser&offset=0&rows=150'

params = {
    'q': 'skitser', 
    'items': 'items',
    'encoding': 'json',
    'n': 150
}

response = requests.get(smk_search_url, params=params)
print(response)
json = response.json()
df = json_normalize(json['items'])
# Out:
# <Response [200]>

# %%
df.head()
# Out:
#   acquisition_date acquisition_date_precision alternative_images collection  \
# 0              NaN                 1992-12-31                NaN        NaN
# 1              NaN                        NaN                NaN        NaN
# 2              NaN                 1982-12-31                NaN        NaN
# 3              NaN                 1982-12-31                NaN        NaN
# 4              NaN                 1978-12-31                NaN        NaN
#
#                                           colors  \
# 0  [#FFFFFF, #D2D2D2, #D2D2D2, #555555, #9B9B9B]
# 1                                            NaN
# 2  [#FFFFFF, #FFFFFF, #D2D2D2, #D2D2D2, #5A5A5A]
# 3  [#D2D2D2, #D2D2D2, #F4C6A3, #555555, #9B9B9B]
# 4                                            NaN
#
#                                  content_description content_subject  \
# 0  [Vandmærke: Bikube på sokkel omgivet af blomst...             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#                 created         credit_line  \
# 0  2019-08-07T05:09:05Z                 NaN
# 1  2019-08-07T07:35:17Z                 NaN
# 2  2019-08-07T03:20:07Z  [© Bjørn Nørgaard]
# 3  2019-08-07T03:21:19Z  [© Bjørn Nørgaard]
# 4  2019-08-07T03:30:59Z   [© Palle Nielsen]
#
#                                           dimensions  ...  \
# 0  [{'notes': '125 x 224 mm', 'part': 'bladmaal',...  ...
# 1  [{'notes': '340 x 440 mm', 'part': 'netto', 't...  ...
# 2  [{'notes': '226 x 157 mm', 'part': 'monterings...  ...
# 3  [{'notes': '143 x 104 mm', 'part': 'monterings...  ...
# 4  [{'notes': '297 x 209 mm', 'part': 'monterings...  ...
#
#                                           production  \
# 0  [{'creator': 'Skovgaard, Niels', 'creator_date...
# 1  [{'creator': 'Tuxen, Lauritz', 'creator_date_o...
# 2  [{'creator': 'Nørgaard, Bjørn', 'creator_date_...
# 3  [{'creator': 'Nørgaard, Bjørn', 'creator_date_...
# 4  [{'creator': 'Nielsen, Palle', 'creator_date_o...
#
#                                      production_date  \
# 0  [{'start': '1923-01-01T00:00:00.000Z', 'end': ...
# 1                                                NaN
# 2  [{'start': '1978-01-01T00:00:00.000Z', 'end': ...
# 3  [{'start': '1965-01-01T00:00:00.000Z', 'end': ...
# 4  [{'start': '1973-01-01T00:00:00.000Z', 'end': ...
#
#                             production_dates_notes public_domain  \
# 0                                              NaN          True
# 1                                              NaN          True
# 2                                              NaN         False
# 3  [Dat. baseret på egenhændig påskrift på blad 2]         False
# 4                                              NaN         False
#
#                                      related_objects  \
# 0  [{'title': 'Illustration til Den lille hvide k...
# 1                                                NaN
# 2  [{'title': 'To studier', 'reference': 'KKS1982...
# 3  [{'title': 'Blank', 'reference': 'KKS1982-138/...
# 4  [{'notes': 'Side 127 i skitsebog med modelstud...
#
#        responsible_department  \
# 0  Samling og Forskning (KKS)
# 1                         NaN
# 2  Samling og Forskning (KKS)
# 3  Samling og Forskning (KKS)
# 4  Samling og Forskning (KKS)
#
#                                               rights  \
# 0  https://creativecommons.org/share-your-work/pu...
# 1  https://creativecommons.org/share-your-work/pu...
# 2            https://en.wikipedia.org/wiki/Copyright
# 3            https://en.wikipedia.org/wiki/Copyright
# 4            https://en.wikipedia.org/wiki/Copyright
#
#                             techniques  \
# 0   [{'technique': 'skitser; blyant'}]
# 1     [{'technique': 'Skitse på træ'}]
# 2            [{'technique': 'Blyant'}]
# 3  [{'technique': 'Sort spritmarker'}]
# 4  [{'technique': 'Pen og sort blæk'}]
#
#                                               titles       work_status
# 0  [{'title': 'Illustration til "Den lille hvide ...               NaN
# 1                 [{'title': 'Arkona, Skitse til '}]               NaN
# 2  [{'title': 'Skitse', 'language': 'da-DK', 'typ...               NaN
# 3  [{'title': 'Skitse', 'language': 'da-DK', 'typ...               NaN
# 4  [{'title': 'Skitse', 'language': 'da-DK', 'typ...  [skitsebogsblad]
#
# [5 rows x 48 columns]

# %%
def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %%
dic_flattened = [flatten_json(d) for d in json['items']]
df= json_normalize(dic_flattened)

# %%
# Hvilke datatyper findes i mit dataframe?
df.dtypes
# Out:
# acquisition_date                     object
# acquisition_date_precision           object
# alternative_images_0_height         float64
# alternative_images_0_iiif_id         object
# alternative_images_0_iiif_info       object
# alternative_images_0_mime_type       object
# alternative_images_0_native          object
# alternative_images_0_orientation     object
# alternative_images_0_size           float64
# alternative_images_0_thumbnail       object
# alternative_images_0_width          float64
# alternative_images_1_height         float64
# alternative_images_1_iiif_id         object
# alternative_images_1_iiif_info       object
# alternative_images_1_mime_type       object
# alternative_images_1_native          object
# alternative_images_1_orientation     object
# alternative_images_1_size           float64
# alternative_images_1_thumbnail       object
# alternative_images_1_width          float64
# alternative_images_2_height         float64
# alternative_images_2_iiif_id         object
# alternative_images_2_iiif_info       object
# alternative_images_2_mime_type       object
# alternative_images_2_native          object
# alternative_images_2_orientation     object
# alternative_images_2_size           float64
# alternative_images_2_thumbnail       object
# alternative_images_2_width          float64
# alternative_images_3_height         float64
#                                      ...
# production_1_creator_nationality     object
# production_1_creator_role            object
# production_date_0_end                object
# production_date_0_period             object
# production_date_0_start              object
# production_date_1_end                object
# production_date_1_period             object
# production_date_1_start              object
# production_dates_notes_0             object
# public_domain                          bool
# related_objects_0_notes              object
# related_objects_0_reference          object
# related_objects_0_title              object
# related_objects_1_reference          object
# related_objects_1_title              object
# responsible_department               object
# rights                               object
# techniques_0_technique               object
# techniques_1_technique               object
# titles_0_language                    object
# titles_0_title                       object
# titles_0_type                        object
# titles_1_language                    object
# titles_1_title                       object
# titles_1_translation                 object
# titles_1_type                        object
# titles_2_language                    object
# titles_2_title                       object
# titles_2_type                        object
# work_status_0                        object
# Length: 324, dtype: object

# %%
df.head()
# Out:
#   acquisition_date acquisition_date_precision  alternative_images_0_height  \
# 0              NaN                 1992-12-31                          NaN
# 1              NaN                        NaN                          NaN
# 2              NaN                 1982-12-31                          NaN
# 3              NaN                 1982-12-31                          NaN
# 4              NaN                 1978-12-31                          NaN
#
#   alternative_images_0_iiif_id alternative_images_0_iiif_info  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
#
#   alternative_images_0_mime_type alternative_images_0_native  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
#
#   alternative_images_0_orientation  alternative_images_0_size  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
#
#   alternative_images_0_thumbnail  ...                          titles_0_title  \
# 0                            NaN  ...  Illustration til "Den lille hvide kat"
# 1                            NaN  ...                     Arkona, Skitse til
# 2                            NaN  ...                                  Skitse
# 3                            NaN  ...                                  Skitse
# 4                            NaN  ...                                  Skitse
#
#    titles_0_type titles_1_language titles_1_title titles_1_translation  \
# 0       DESCRIPT               NaN            NaN                  NaN
# 1            NaN               NaN            NaN                  NaN
# 2       DESCRIPT               NaN            NaN                  NaN
# 3       DESCRIPT               NaN            NaN                  NaN
# 4         MUSEUM               NaN            NaN                  NaN
#
#   titles_1_type titles_2_language  titles_2_title titles_2_type  \
# 0           NaN               NaN             NaN           NaN
# 1           NaN               NaN             NaN           NaN
# 2           NaN               NaN             NaN           NaN
# 3           NaN               NaN             NaN           NaN
# 4           NaN               NaN             NaN           NaN
#
#     work_status_0
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4  skitsebogsblad
#
# [5 rows x 324 columns]

# %%
# Ovenstående liste vil også bruges til at fjerne kolonner som ikke har interesse
df = df[df.columns.drop(list(df.filter(regex='alternative_images_[0-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='titles_[0-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='production_[0-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='production_date_[0-9]{1,3}_([^\s]+)')))]

# %%
df.dtypes
# Out:
# acquisition_date               object
# acquisition_date_precision     object
# collection_0                   object
# colors_0                       object
# colors_1                       object
# colors_2                       object
# colors_3                       object
# colors_4                       object
# content_description_0          object
# content_description_1          object
# content_subject_0              object
# created                        object
# credit_line_0                  object
# dimensions_0_notes             object
# dimensions_0_part              object
# dimensions_0_type              object
# dimensions_0_unit              object
# dimensions_0_value             object
# dimensions_1_notes             object
# dimensions_1_part              object
# dimensions_1_type              object
# dimensions_1_unit              object
# dimensions_1_value             object
# dimensions_2_notes             object
# dimensions_2_part              object
# dimensions_2_type              object
# dimensions_2_unit              object
# dimensions_2_value             object
# dimensions_3_notes             object
# dimensions_3_part              object
#                                 ...
# parts_39                       object
# parts_4                        object
# parts_40                       object
# parts_41                       object
# parts_42                       object
# parts_43                       object
# parts_44                       object
# parts_45                       object
# parts_46                       object
# parts_47                       object
# parts_48                       object
# parts_49                       object
# parts_5                        object
# parts_50                       object
# parts_6                        object
# parts_7                        object
# parts_8                        object
# parts_9                        object
# production_dates_notes_0       object
# public_domain                    bool
# related_objects_0_notes        object
# related_objects_0_reference    object
# related_objects_0_title        object
# related_objects_1_reference    object
# related_objects_1_title        object
# responsible_department         object
# rights                         object
# techniques_0_technique         object
# techniques_1_technique         object
# work_status_0                  object
# Length: 206, dtype: object

# %%
df.shape
# Out:
# (150, 206)

# %%
df = df[df.columns.drop(list(df.filter(regex='related_[0-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='related_objects_[0-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='techniques_[0-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='work_status_[0-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='production_dates_notes_[0-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='content_description_[0-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='parts_[0-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='alternative_images_[0-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='titles_[0-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='production_[1-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='production_date_[0-9]{1,3}_([^\s]+)')))]

# %%
df.shape
# Out:
# (150, 199)

# %%
df.head()
# Out:
#   acquisition_date acquisition_date_precision collection_0 colors_0 colors_1  \
# 0              NaN                 1992-12-31          NaN  #FFFFFF  #D2D2D2
# 1              NaN                        NaN          NaN      NaN      NaN
# 2              NaN                 1982-12-31          NaN  #FFFFFF  #FFFFFF
# 3              NaN                 1982-12-31          NaN  #D2D2D2  #D2D2D2
# 4              NaN                 1978-12-31          NaN      NaN      NaN
#
#   colors_2 colors_3 colors_4  \
# 0  #D2D2D2  #555555  #9B9B9B
# 1      NaN      NaN      NaN
# 2  #D2D2D2  #D2D2D2  #5A5A5A
# 3  #F4C6A3  #555555  #9B9B9B
# 4      NaN      NaN      NaN
#
#                                content_description_0 content_description_1  \
# 0  Vandmærke: Bikube på sokkel omgivet af blomste...                   NaN
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
#
#    ... parts_50 parts_6 parts_7 parts_8 parts_9  \
# 0  ...      NaN     NaN     NaN     NaN     NaN
# 1  ...      NaN     NaN     NaN     NaN     NaN
# 2  ...      NaN     NaN     NaN     NaN     NaN
# 3  ...      NaN     NaN     NaN     NaN     NaN
# 4  ...      NaN     NaN     NaN     NaN     NaN
#
#                         production_dates_notes_0 public_domain  \
# 0                                            NaN          True
# 1                                            NaN          True
# 2                                            NaN         False
# 3  Dat. baseret på egenhændig påskrift på blad 2         False
# 4                                            NaN         False
#
#        responsible_department  \
# 0  Samling og Forskning (KKS)
# 1                         NaN
# 2  Samling og Forskning (KKS)
# 3  Samling og Forskning (KKS)
# 4  Samling og Forskning (KKS)
#
#                                               rights   work_status_0
# 0  https://creativecommons.org/share-your-work/pu...             NaN
# 1  https://creativecommons.org/share-your-work/pu...             NaN
# 2            https://en.wikipedia.org/wiki/Copyright             NaN
# 3            https://en.wikipedia.org/wiki/Copyright             NaN
# 4            https://en.wikipedia.org/wiki/Copyright  skitsebogsblad
#
# [5 rows x 199 columns]

# %%
df.shape
# Out:
# (150, 199)

# %%
df.dtypes
# Out:
# acquisition_date              object
# acquisition_date_precision    object
# collection_0                  object
# colors_0                      object
# colors_1                      object
# colors_2                      object
# colors_3                      object
# colors_4                      object
# content_description_0         object
# content_description_1         object
# content_subject_0             object
# created                       object
# credit_line_0                 object
# dimensions_0_notes            object
# dimensions_0_part             object
# dimensions_0_type             object
# dimensions_0_unit             object
# dimensions_0_value            object
# dimensions_1_notes            object
# dimensions_1_part             object
# dimensions_1_type             object
# dimensions_1_unit             object
# dimensions_1_value            object
# dimensions_2_notes            object
# dimensions_2_part             object
# dimensions_2_type             object
# dimensions_2_unit             object
# dimensions_2_value            object
# dimensions_3_notes            object
# dimensions_3_part             object
#                                ...
# parts_32                      object
# parts_33                      object
# parts_34                      object
# parts_35                      object
# parts_36                      object
# parts_37                      object
# parts_38                      object
# parts_39                      object
# parts_4                       object
# parts_40                      object
# parts_41                      object
# parts_42                      object
# parts_43                      object
# parts_44                      object
# parts_45                      object
# parts_46                      object
# parts_47                      object
# parts_48                      object
# parts_49                      object
# parts_5                       object
# parts_50                      object
# parts_6                       object
# parts_7                       object
# parts_8                       object
# parts_9                       object
# production_dates_notes_0      object
# public_domain                   bool
# responsible_department        object
# rights                        object
# work_status_0                 object
# Length: 199, dtype: object

# %%
# Regex automatisering af fjernelse af kolonner som jeg ikke vil have i mit dataframe, efter flattening
# Jeg går herved ned fra 300+ kolonner til 18
# Credit: (Frederik)
df = df[df.columns.drop(list(df.filter(regex='parts_[0-9]{1,3}')))]
df = df[df.columns.drop(list(df.filter(regex='documentation_[0-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='part_of_[0-9]{1,3}')))]
df = df[df.columns.drop(list(df.filter(regex='inscriptions_[0-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='exhibitions_[0-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='content_description_[0-9]{1,3}')))]
df = df[df.columns.drop(list(df.filter(regex='image_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='materials_[0-9]{1,3}_([^\s]+)')))]
df = df[df.columns.drop(list(df.filter(regex='frame_notes_[0-9]{1,3}')))]
df = df[df.columns.drop(list(df.filter(regex='dimensions_[0-9]{1,3}_([^\s]+)')))]

# %%
df.shape
# Out:
# (150, 27)

# %%
df.dtypes
# Out:
# acquisition_date               object
# acquisition_date_precision     object
# collection_0                   object
# colors_0                       object
# colors_1                       object
# colors_2                       object
# colors_3                       object
# colors_4                       object
# content_subject_0              object
# created                        object
# credit_line_0                  object
# distinguishing_features_0      object
# has_image                        bool
# id                             object
# iiif_manifest                  object
# modified                       object
# notes_0                        object
# number_of_parts               float64
# object_history_note_0          object
# object_names_0_name            object
# object_number                  object
# on_display                       bool
# production_dates_notes_0       object
# public_domain                    bool
# responsible_department         object
# rights                         object
# work_status_0                  object
# dtype: object

# %%
df.head()
# Out:
#   acquisition_date acquisition_date_precision collection_0 colors_0 colors_1  \
# 0              NaN                 1992-12-31          NaN  #FFFFFF  #D2D2D2
# 1              NaN                        NaN          NaN      NaN      NaN
# 2              NaN                 1982-12-31          NaN  #FFFFFF  #FFFFFF
# 3              NaN                 1982-12-31          NaN  #D2D2D2  #D2D2D2
# 4              NaN                 1978-12-31          NaN      NaN      NaN
#
#   colors_2 colors_3 colors_4 content_subject_0               created  ...  \
# 0  #D2D2D2  #555555  #9B9B9B               NaN  2019-08-07T05:09:05Z  ...
# 1      NaN      NaN      NaN               NaN  2019-08-07T07:35:17Z  ...
# 2  #D2D2D2  #D2D2D2  #5A5A5A               NaN  2019-08-07T03:20:07Z  ...
# 3  #F4C6A3  #555555  #9B9B9B               NaN  2019-08-07T03:21:19Z  ...
# 4      NaN      NaN      NaN               NaN  2019-08-07T03:30:59Z  ...
#
#   number_of_parts                              object_history_note_0  \
# 0             1.0          Poula Garde. Erhvervet herfra af KKS 1992
# 1             NaN                                                NaN
# 2            83.0  Købt af kunstneren i forbindelse med udstillin...
# 3           238.0  Købt af kunstneren i forbindelse med udstillin...
# 4            78.0                          Gave 1978 fra kunstneren.
#
#    object_names_0_name         object_number on_display  \
# 0              tegning     KKS1992-281 verso      False
# 1                  NaN                EKS720      False
# 2              tegning  KKS1982-140/17 verso      False
# 3              tegning  KKS1982-138/98 verso      False
# 4                  pen         KKS1978-42/64      False
#
#                         production_dates_notes_0 public_domain  \
# 0                                            NaN          True
# 1                                            NaN          True
# 2                                            NaN         False
# 3  Dat. baseret på egenhændig påskrift på blad 2         False
# 4                                            NaN         False
#
#        responsible_department  \
# 0  Samling og Forskning (KKS)
# 1                         NaN
# 2  Samling og Forskning (KKS)
# 3  Samling og Forskning (KKS)
# 4  Samling og Forskning (KKS)
#
#                                               rights   work_status_0
# 0  https://creativecommons.org/share-your-work/pu...             NaN
# 1  https://creativecommons.org/share-your-work/pu...             NaN
# 2            https://en.wikipedia.org/wiki/Copyright             NaN
# 3            https://en.wikipedia.org/wiki/Copyright             NaN
# 4            https://en.wikipedia.org/wiki/Copyright  skitsebogsblad
#
# [5 rows x 27 columns]

# %%
df.dtypes
# Out:
# acquisition_date               object
# acquisition_date_precision     object
# collection_0                   object
# colors_0                       object
# colors_1                       object
# colors_2                       object
# colors_3                       object
# colors_4                       object
# content_subject_0              object
# created                        object
# credit_line_0                  object
# distinguishing_features_0      object
# has_image                        bool
# id                             object
# iiif_manifest                  object
# modified                       object
# notes_0                        object
# number_of_parts               float64
# object_history_note_0          object
# object_names_0_name            object
# object_number                  object
# on_display                       bool
# production_dates_notes_0       object
# public_domain                    bool
# responsible_department         object
# rights                         object
# work_status_0                  object
# dtype: object

# %%
to_drop = ['content_subject_0', 
           'created', 
           'object_number', 
           'production_dates_notes_0', 
           'distinguishing_features_0', 
           'modified', 
           'notes_0',
           'iiif_manifest',
          'object_history_note_0',
           'object_names_0_name',
          'work_status_0']

df.drop(to_drop, inplace=True, axis=1)

# %%
df.head()
# Out:
#   acquisition_date acquisition_date_precision collection_0 colors_0 colors_1  \
# 0              NaN                 1992-12-31          NaN  #FFFFFF  #D2D2D2
# 1              NaN                        NaN          NaN      NaN      NaN
# 2              NaN                 1982-12-31          NaN  #FFFFFF  #FFFFFF
# 3              NaN                 1982-12-31          NaN  #D2D2D2  #D2D2D2
# 4              NaN                 1978-12-31          NaN      NaN      NaN
#
#   colors_2 colors_3 colors_4     credit_line_0  has_image                 id  \
# 0  #D2D2D2  #555555  #9B9B9B               NaN       True  1180034853_object
# 1      NaN      NaN      NaN               NaN      False  1180072921_object
# 2  #D2D2D2  #D2D2D2  #5A5A5A  © Bjørn Nørgaard       True  1180000116_object
# 3  #F4C6A3  #555555  #9B9B9B  © Bjørn Nørgaard       True  1180000333_object
# 4      NaN      NaN      NaN   © Palle Nielsen      False  1180002715_object
#
#    number_of_parts  on_display  public_domain      responsible_department  \
# 0              1.0       False           True  Samling og Forskning (KKS)
# 1              NaN       False           True                         NaN
# 2             83.0       False          False  Samling og Forskning (KKS)
# 3            238.0       False          False  Samling og Forskning (KKS)
# 4             78.0       False          False  Samling og Forskning (KKS)
#
#                                               rights
# 0  https://creativecommons.org/share-your-work/pu...
# 1  https://creativecommons.org/share-your-work/pu...
# 2            https://en.wikipedia.org/wiki/Copyright
# 3            https://en.wikipedia.org/wiki/Copyright
# 4            https://en.wikipedia.org/wiki/Copyright

# %%
# Undersøger om kolonne med id er unique
# Den er true, så derfor vil jeg erstatte min DF index med id
df['id'].is_unique
# Out:
# True

# %%
df.set_index('id', inplace=True)
# view the first 5 rows of the df
df.head()
# Out:
#                   acquisition_date acquisition_date_precision collection_0  \
# id
# 1180034853_object              NaN                 1992-12-31          NaN
# 1180072921_object              NaN                        NaN          NaN
# 1180000116_object              NaN                 1982-12-31          NaN
# 1180000333_object              NaN                 1982-12-31          NaN
# 1180002715_object              NaN                 1978-12-31          NaN
#
#                   colors_0 colors_1 colors_2 colors_3 colors_4  \
# id
# 1180034853_object  #FFFFFF  #D2D2D2  #D2D2D2  #555555  #9B9B9B
# 1180072921_object      NaN      NaN      NaN      NaN      NaN
# 1180000116_object  #FFFFFF  #FFFFFF  #D2D2D2  #D2D2D2  #5A5A5A
# 1180000333_object  #D2D2D2  #D2D2D2  #F4C6A3  #555555  #9B9B9B
# 1180002715_object      NaN      NaN      NaN      NaN      NaN
#
#                       credit_line_0  has_image  number_of_parts  on_display  \
# id
# 1180034853_object               NaN       True              1.0       False
# 1180072921_object               NaN      False              NaN       False
# 1180000116_object  © Bjørn Nørgaard       True             83.0       False
# 1180000333_object  © Bjørn Nørgaard       True            238.0       False
# 1180002715_object   © Palle Nielsen      False             78.0       False
#
#                    public_domain      responsible_department  \
# id
# 1180034853_object           True  Samling og Forskning (KKS)
# 1180072921_object           True                         NaN
# 1180000116_object          False  Samling og Forskning (KKS)
# 1180000333_object          False  Samling og Forskning (KKS)
# 1180002715_object          False  Samling og Forskning (KKS)
#
#                                                               rights
# id
# 1180034853_object  https://creativecommons.org/share-your-work/pu...
# 1180072921_object  https://creativecommons.org/share-your-work/pu...
# 1180000116_object            https://en.wikipedia.org/wiki/Copyright
# 1180000333_object            https://en.wikipedia.org/wiki/Copyright
# 1180002715_object            https://en.wikipedia.org/wiki/Copyright

# %%
extr = df['acquisition_date_precision'].str.extract(r'^(\d{4})', expand=False)
df['acquisition year'] = pd.to_numeric(extr)

# %%
df.head()
# Out:
#                   acquisition_date acquisition_date_precision collection_0  \
# id
# 1180034853_object              NaN                 1992-12-31          NaN
# 1180072921_object              NaN                        NaN          NaN
# 1180000116_object              NaN                 1982-12-31          NaN
# 1180000333_object              NaN                 1982-12-31          NaN
# 1180002715_object              NaN                 1978-12-31          NaN
#
#                   colors_0 colors_1 colors_2 colors_3 colors_4  \
# id
# 1180034853_object  #FFFFFF  #D2D2D2  #D2D2D2  #555555  #9B9B9B
# 1180072921_object      NaN      NaN      NaN      NaN      NaN
# 1180000116_object  #FFFFFF  #FFFFFF  #D2D2D2  #D2D2D2  #5A5A5A
# 1180000333_object  #D2D2D2  #D2D2D2  #F4C6A3  #555555  #9B9B9B
# 1180002715_object      NaN      NaN      NaN      NaN      NaN
#
#                       credit_line_0  has_image  number_of_parts  on_display  \
# id
# 1180034853_object               NaN       True              1.0       False
# 1180072921_object               NaN      False              NaN       False
# 1180000116_object  © Bjørn Nørgaard       True             83.0       False
# 1180000333_object  © Bjørn Nørgaard       True            238.0       False
# 1180002715_object   © Palle Nielsen      False             78.0       False
#
#                    public_domain      responsible_department  \
# id
# 1180034853_object           True  Samling og Forskning (KKS)
# 1180072921_object           True                         NaN
# 1180000116_object          False  Samling og Forskning (KKS)
# 1180000333_object          False  Samling og Forskning (KKS)
# 1180002715_object          False  Samling og Forskning (KKS)
#
#                                                               rights  \
# id
# 1180034853_object  https://creativecommons.org/share-your-work/pu...
# 1180072921_object  https://creativecommons.org/share-your-work/pu...
# 1180000116_object            https://en.wikipedia.org/wiki/Copyright
# 1180000333_object            https://en.wikipedia.org/wiki/Copyright
# 1180002715_object            https://en.wikipedia.org/wiki/Copyright
#
#                    acquisition year
# id
# 1180034853_object            1992.0
# 1180072921_object               NaN
# 1180000116_object            1982.0
# 1180000333_object            1982.0
# 1180002715_object            1978.0

# %%
to_drop = ['acquisition_date',
          'acquisition_date_precision',
          'collection_0',
          'rights']
# drop the columns listed in "to_drop" in the dataframe
df.drop(to_drop, inplace=True, axis=1)
# view the first 5 rows of the df
df.head()
# Out:
#                   colors_0 colors_1 colors_2 colors_3 colors_4  \
# id
# 1180034853_object  #FFFFFF  #D2D2D2  #D2D2D2  #555555  #9B9B9B
# 1180072921_object      NaN      NaN      NaN      NaN      NaN
# 1180000116_object  #FFFFFF  #FFFFFF  #D2D2D2  #D2D2D2  #5A5A5A
# 1180000333_object  #D2D2D2  #D2D2D2  #F4C6A3  #555555  #9B9B9B
# 1180002715_object      NaN      NaN      NaN      NaN      NaN
#
#                       credit_line_0  has_image  number_of_parts  on_display  \
# id
# 1180034853_object               NaN       True              1.0       False
# 1180072921_object               NaN      False              NaN       False
# 1180000116_object  © Bjørn Nørgaard       True             83.0       False
# 1180000333_object  © Bjørn Nørgaard       True            238.0       False
# 1180002715_object   © Palle Nielsen      False             78.0       False
#
#                    public_domain      responsible_department  acquisition year
# id
# 1180034853_object           True  Samling og Forskning (KKS)            1992.0
# 1180072921_object           True                         NaN               NaN
# 1180000116_object          False  Samling og Forskning (KKS)            1982.0
# 1180000333_object          False  Samling og Forskning (KKS)            1982.0
# 1180002715_object          False  Samling og Forskning (KKS)            1978.0

# %%
import altair as alt
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
# Diagrammet viser om der findes billeder af skitserne i SKM databasen, og hvilke årstal der har billeder,
# samt de år som ikke har billeder af skitserne
alt.Chart(df).mark_line(point=True).encode(
        # Years on the X axis with encoding data type Q for quantitative and format c to display without decimal
        x=alt.X('acquisition year:Q', axis=alt.Axis(format='c', title='Acquisition Year')),
    
        # Number of articles on the Y axis  with encoding data type Q for quantitative
        y=alt.Y('has_image:Q', axis=alt.Axis(title='Has Image')),
    
    # determine the width and hight  
    ).properties(width=700, height=300)

# %%
alt.Chart(df).mark_line(point=True).encode(
        # Years on the X axis with encoding data type Q for quantitative and format c to display without decimal
        x=alt.X('acquisition year:Q', axis=alt.Axis(format='c', title='Acquisition Year')),
    
        # Number of articles on the Y axis  with encoding data type Q for quantitative
        y=alt.Y('public_domain:Q', axis=alt.Axis(title='Has Image')),
    
    # determine the width and hight  
    ).properties(width=700, height=300)

# %%
publicdomain = df['public_domain'].value_counts()
publicdomainprocent = df['public_domain'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
domaindf = pd.DataFrame(columns=['Antal', 'Procent'], index=['Public Domain', 'Ikke Public',], data=zip(publicdomain,publicdomainprocent))
print(domaindf)
# Out:
#                Antal Procent
# Public Domain    100   66.7%
# Ikke Public       50   33.3%

# %%
domainbar = df['public_domain'].value_counts()[:2].plot(kind='bar')

# %%
imagebar = df['has_image'].value_counts()[:2].plot(kind='bar')

# %%
colorcount = df['colors_0'].value_counts()
colorcountper = df['colors_0'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
colors = pd.DataFrame(columns=['Antal', 'Procent'], index=['#9B9B9B', '#D2D2D2', '#FFFFFF', '#F4C6A3', '#5A5A5A'], data=zip(colorcount,colorcountper))
print(colors)
# Out:
#          Antal Procent
# #9B9B9B     21   30.4%
# #D2D2D2     20   29.0%
# #FFFFFF     16   23.2%
# #F4C6A3     11   15.9%
# #5A5A5A      1    1.4%

# %%
colorbar = df['colors_1'].value_counts()[:5].plot(kind='bar')

# %%
partscount = df['number_of_parts'].value_counts()
